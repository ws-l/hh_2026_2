# %% [markdown]
# #1. 선형회귀분석

# %% [markdown]
# ##1) 선형성, 데이터

# %%
import pandas as pd
import numpy as np
import scipy as sp

data = pd.read_csv("adv.csv")

# %%
A=data.TV
B=data.sales

# %%
print(sp.stats.pearsonr(A,B))   #상관관계
# Out:
# PearsonRResult(statistic=np.float64(0.7822244248616067), pvalue=np.float64(1.4673897001946247e-42))

# %% [markdown]
#  - 데이터파티셔닝/스케일링 등

# %%
#X변수: TV, radio, newspaper, Y변수: sales
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
variables = ["sales","TV","newspaper","radio"]
df = pd.DataFrame( StandardScaler().fit_transform(data[variables]),
                  columns=variables)
train, test = train_test_split( df, test_size=0.2)

# %% [markdown]
# - 다중공선성(Multi colinearity)
#  - 다중공선성이 있으면 X변수들에 따라 계수가 변동

# %%
df.corr()#method='spearman')
# Out:
#               sales        TV  newspaper     radio
# sales      1.000000  0.782224   0.228299  0.576223
# TV         0.782224  1.000000   0.056648  0.054809
# newspaper  0.228299  0.056648   1.000000  0.354104
# radio      0.576223  0.054809   0.354104  1.000000

# %% [markdown]
# - 다중공선성 확인
#   - 5를 초과하는 값이 있는지 확인

# %%
# Use variance inflation factor to identify any significant multi-collinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(df):
    vif = pd.DataFrame()
    vif["variables"] = df.columns
    vif["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return(vif)

calc_vif(df[["TV","newspaper","radio"]])
# Out:
#    variables       VIF
# 0         TV  1.004611
# 1  newspaper  1.145187
# 2      radio  1.144952

# %% [markdown]
# ##2) statmodels 사용

# %%
import statsmodels.api as sm
reg = sm.OLS.from_formula("sales ~TV+radio+newspaper", df).fit()  #train
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):           1.58e-96
# Time:                        12:08:39   Log-Likelihood:                -56.280
# No. Observations:                 200   AIC:                             120.6
# Df Residuals:                     196   BIC:                             133.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.527e-16      0.023  -6.67e-15      1.000      -0.045       0.045
# TV             0.7531      0.023     32.809      0.000       0.708       0.798
# radio          0.5365      0.025     21.893      0.000       0.488       0.585
# newspaper     -0.0043      0.025     -0.177      0.860      -0.053       0.044
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         1.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.formula.api import ols
model = ols(formula = "sales ~TV+radio+newspaper",data = train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     447.3
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):           2.25e-76
# Time:                        12:08:39   Log-Likelihood:                -44.882
# No. Observations:                 160   AIC:                             97.76
# Df Residuals:                     156   BIC:                             110.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0080      0.026      0.311      0.756      -0.043       0.059
# TV             0.7546      0.026     28.815      0.000       0.703       0.806
# radio          0.5248      0.028     18.831      0.000       0.470       0.580
# newspaper     -0.0009      0.028     -0.033      0.974      -0.056       0.055
# ==============================================================================
# Omnibus:                       59.715   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              172.646
# Skew:                          -1.505   Prob(JB):                     3.24e-38
# Kurtosis:                       7.103   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model.predict( test )
# Out:
# 6     -0.442833
# 28     1.040893
# 78    -1.004089
# 113    0.465657
# 71    -0.637902
# 41     0.630785
# 74     0.640785
# 168    0.621072
# 112   -0.016977
# 47     1.472941
# 198    1.873697
# 148   -0.348393
# 34    -1.218241
# 33     0.938297
# 81     0.145952
# 26     0.186129
# 69     1.354066
# 121   -1.178340
# 165    0.072400
# 94    -0.668793
# 128    1.566657
# 132   -1.073020
# 60    -1.569432
# 197   -0.221855
# 10    -1.323865
# 73    -0.769928
# 178    0.407884
# 192   -1.815318
# 149   -0.803554
# 25     0.328984
# 134   -0.420620
# 44    -0.980777
# 37     0.296027
# 65    -1.173289
# 183    1.944141
# 96    -0.245843
# 83     0.067305
# 141    0.847239
# 12    -0.660094
# 103    0.153650
# dtype: float64

# %%
pred = model.predict(test)
np.sqrt( np.mean( (pred-test.sales)**2 ) ) #RMSE
# Out:
# np.float64(0.32317462113146184)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error( pred, test.sales)  #MSE
# Out:
# 0.10444183574346391

# %% [markdown]
# ##3) sklearn 이용

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
line_fitter = LinearRegression().fit(df[["TV","radio"]], df.sales)
line_fitter.coef_
line_fitter.intercept_
#line_fitter.fit(train_df.drop('sales', axis=1), train_df.sales)
# Out:
# np.float64(-1.838200703291171e-17)

# %%
#df에 scaling을 적용, StandardScaler를 사용
from sklearn.preprocessing import StandardScaler
df = pd.DataFrame( StandardScaler().fit_transform(df), columns=df.columns)
#scaler = StandardScaler()
#scaled = scaler.fit_transform( df )
#df = pd.DataFrame( scaled, columns=df.columns)
#df를 train, test로 파티셔닝
train, test = train_test_split( df, test_size=0.2)
model = LinearRegression().fit( train.drop(['sales'], axis=1),
                               train.sales)

# %%
model.feature_names_in_
# Out:
# array(['TV', 'newspaper', 'radio'], dtype=object)

# %%
#X변수: TV, radio, newspaper, Y변수: sales
#model.coef_, model.intercept_
pred = model.predict(  test[["TV", "newspaper", "radio"]] )

# %%
import numpy as np
np.mean(   (pred - test.sales)**2  )  #Mean Squared Error
np.sqrt( np.mean(   (pred - test.sales)**2  ) ) #Rooted Mean Squared Error
# Out:
# np.float64(0.3020066916795441)

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
variables = ["sales","TV","newspaper","radio"]
df = pd.DataFrame( StandardScaler().fit_transform(data[variables]),columns=variables)
train, test = train_test_split( df, test_size=0.2)

# %%
imputer = SimpleImputer(strategy='mean')
imputer.fit(df)
df3_imputed = imputer.transform(df)
df3_imputed_df = pd.DataFrame( df3_imputed )
df3_imputed_df.plot.box()
# Out:
# <Axes: >

# %%
scaler = StandardScaler()
df3_scaled = scaler.fit_transform(df3_imputed)
train, test = train_test_split( df3_scaled, test_size=0.3)
train_df = pd.DataFrame( train, columns = df.columns)
test_df = pd.DataFrame( test, columns = df.columns)

# %%
train_df
# Out:
#         sales        TV  newspaper     radio
# 0    2.205347  1.594565   1.640850  1.265121
# 1    0.187822  1.602739  -1.111852 -0.855118
# 2    0.091749  0.203849   0.775452 -0.159626
# 3   -0.446257  0.270407   0.213864 -1.044184
# 4    1.110119  1.265277  -1.153281  0.245516
# ..        ...       ...        ...       ...
# 135  1.283050  1.064435  -1.162487  0.745190
# 136 -0.715261 -0.078731  -0.992170 -1.442573
# 137  0.591327  0.349810   0.374975  0.684419
# 138 -1.637558 -1.631756   0.499261  0.326544
# 139  0.360753 -0.249214   2.239264  0.920751
#
# [140 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
line_fitter = LinearRegression()
line_fitter.fit(train_df.drop('sales', axis=1), train_df.sales)
# Out:
# LinearRegression()

# %%
y_predicted = line_fitter.predict(test_df.drop('sales', axis=1))

# %%
np.mean( (y_predicted-test_df.sales)**2 )
# Out:
# np.float64(0.1475860447465077)

# %% [markdown]
# #2. 실습1: 가스생산량

# %% [markdown]
# - Well
#  - 시추공 식별자 (Well Index). 특정 지층 단면 또는 생산지역을 구분하는 고유 번호로, 각 샘플이 어느 시추공에서 측정되었는지를 나타냄.
# - Por
#  - 평균 공극률 (Porosity, %). 암석 내 유체가 채워질 수 있는 공간의 비율로, 저류능력과 밀접한 관련. 높은 공극률은 일반적으로 저장 용량이 큰 셰일을 의미.
# - Perm
#  - 투과율 (Permeability, mD). 유체가 암석을 통해 얼마나 잘 흐를 수 있는지를 나타내며, 높은 투과율은 생산성이 좋은 셰일층을 의미. 단위는 밀리다시(mD, millidarcy)
# - AI
# 	- 음향 임피던스 (Acoustic Impedance, kg/m²s × 10⁶). 암석의 밀도와 탄성에 의해 결정되며, 지층의 물리적 특성과 반사율을 예측하는 데 사용. 지진파 해석에서 핵심 변수.
# - Brittle
#  - 취성 비율 (Brittleness Ratio, %). 암석이 얼마나 쉽게 깨질 수 있는지를 나타내며, Hydraulic Fracturing(수압파쇄) 가능성과 관련. 높은 값일수록 균열이 잘 발생하는 경향
# - TOC
#  - 총 유기탄소 함량 (Total Organic Carbon, %). 셰일층 내 포함된 유기물질의 비율로, 유기물로부터 가스 또는 오일 생성 가능성. 주요 원소로는 탄소(C)가 포함
# - VR
#  - 	비트리나이트 반사율 (Vitrinite Reflectance, %). 유기물의 열성숙도(thermal maturity)를 나타내는 지표로, 셰일 가스 또는 오일의 생성 가능성과 직결. 일반적으로 0.6~1.2%가 가스 생성에 적합한 성숙도.
# - Prod
#  - 하루당 가스 생산량 (Gas Production per Day, MCFD). 하루 동안 생산된 가스량(MCF/day 단위, thousand cubic feet per day)으로, 본 예제의 종속변수 (Response Variable). 암석 특성과 생산성과의 관계를 예측하는 데 사용

# %%
import pandas as pd
from sklearn import linear_model
import numpy as np

df = pd.read_csv('unconv_MV_v5.csv')

# %%
import numpy as np
features = ['Por']
target = 'Prod'
df[features].values.reshape(-1, len(features)).shape #200,1
# Out:
# (200, 1)

# %%
#X변수가 1개인 경우에만 아래처럼
X = df[features].values.reshape(-1, len(features))  #2차원으로 변경 필요
y = df[target].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (200, 1)
# (200,)

# %%
ols = linear_model.LinearRegression()
model = ols.fit(X, y)

# %%
print( model.coef_ )
model.intercept_
# Out:
# [287.78074285]
# np.float64(-2.9444310537137426)

# %%
model.score(X, y) #R-squared
# Out:
# 0.7428880535051593

# %% [markdown]
# - porosity 15%에서의 Production?

# %%
x_pred = np.array([15])
x_pred = x_pred.reshape(-1, len(features))
model.predict(x_pred)
# Out:
# array([4313.76671169])

# %%
x_pred = np.array([14, 18])
x_pred = x_pred.reshape(-1, len(features))
model.predict(x_pred)
# Out:
# array([4025.98596884, 5177.10894024])

# %%
# 위의 자료를 이용、 X변수는 por, brittle, toc, y변수는 prod
X=df[["Por", "Brittle", "TOC"]]
y=df.Prod
# x변수는 standard scaling
scaled = StandardScaler().fit_transform( X )
# 7:3으로 파티셔닝,
X_train, X_test, y_train, y_test = train_test_split( scaled, y, test_size=0.3)
# train으로 회귀모형
model = LinearRegression().fit( X_train, y_train )
print( model.score(X_train, y_train))
# test로 RMSE 계산
np.sqrt( np.mean( (model.predict( X_test) - y_test)**2 ) )
# Out:
# 0.9422969043110921
# np.float64(205.3400145101062)

# %% [markdown]
# - DV

# %%
x_pred = X[0:5]
y_pred = model.predict(x_pred)
# Out:
# c:\Users\user\miniconda3\envs\day3\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# - 다중회귀

# %%
features = ['Por', 'Brittle', 'Perm', 'TOC']
target = 'Prod'

X = df[features].values.reshape(-1, len(features))
y = df[target].values

ols = linear_model.LinearRegression()
model = ols.fit(X, y)

# %%
print(model.coef_)
model.intercept_
# Out:
# [244.60011793  31.58801063  86.87367291 325.19354135]
# np.float64(-1575.2734966267117)

# %%
model.score(X, y)
# Out:
# 0.9516996043535946

# %% [markdown]
#  - Por = 12 (%)
#  - Brittle = 81 (%)
#  - VR = 2.31 (%)
#  - AI = 2.8 (kg/m2s*10^6)

# %%
x_pred = np.array([12, 81, 2.31, 2.8])
x_pred = x_pred.reshape(-1, len(features))
model.predict(x_pred)
# Out:
# array([5029.77688021])

# %% [markdown]
# - 다중공선성(Multi colinearity)
#  - 다중공선성이 있으면 X변수들에 따라 계수가 변동

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('unconv_MV_v5.csv')
df = df.iloc[:, 1:-1] #x변수들만

corr = df.corr(method='spearman')

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True, sep=100)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0, linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# - 선형회귀모형 시각화

# %%
df = pd.read_csv("unconv_MV_v5.csv")
df.head(10)
# Out:
#    Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0     1  12.08  2.92  2.80    81.40  1.16  2.31  4165.196191
# 1     2  12.38  3.53  3.22    46.17  0.89  1.88  3561.146205
# 2     3  14.02  2.59  4.01    72.80  0.89  2.72  4284.348574
# 3     4  17.67  6.75  2.63    39.81  1.08  1.88  5098.680869
# 4     5  17.52  4.57  3.18    10.94  1.51  1.90  3406.132832
# 5     6  14.53  4.81  2.69    53.60  0.94  1.67  4395.763259
# 6     7  13.49  3.60  2.93    63.71  0.80  1.85  4104.400989
# 7     8  11.58  3.03  3.25    53.00  0.69  1.93  3496.742701
# 8     9  12.52  2.72  2.43    65.77  0.95  1.98  4025.851153
# 9    10  13.25  3.94  3.71    66.20  1.14  2.65  4285.026122

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#데이터 준비
X = df[['Por', 'Brittle']].values.reshape(-1,2)
Y = df['Prod']

x = X[:, 0]
y = X[:, 1]
z = Y

x_pred = np.linspace(6, 24, 30)   # range of porosity values
y_pred = np.linspace(0, 100, 30)  # range of brittleness values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

#학습
ols = linear_model.LinearRegression()
model = ols.fit(X, Y)
predicted = model.predict(model_viz)
r2 = model.score(X, Y)

plt.style.use('default')
fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')
axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('Brittleness', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

#각도 조정
ax1.view_init(elev=28, azim=120)
ax2.view_init(elev=4, azim=114)
ax3.view_init(elev=60, azim=165)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)
fig.tight_layout()

# %% [markdown]
# - 다른 시각화

# %%
X = df[['Por', 'VR']].values.reshape(-1,2)
Y = df['Prod']

x = X[:, 0]
y = X[:, 1]
z = Y

x_pred = np.linspace(6, 24, 30)      # range of porosity values
y_pred = np.linspace(0.93, 2.9, 30)  # range of VR values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

#학습
ols = linear_model.LinearRegression()
model = ols.fit(X, Y)
predicted = model.predict(model_viz)
r2 = model.score(X, Y)

#시각화

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, color='k', zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('VR', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.view_init(elev=27, azim=112)
ax2.view_init(elev=16, azim=-51)
ax3.view_init(elev=60, azim=165)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()

# %% [markdown]
# #3. statmodels 사용

# %%
features = ['Por', 'Brittle', 'Perm', 'TOC']
target = 'Prod'

X = df[features]  #.values.reshape(-1, len(features))
y = df[target].values

# %%
import statsmodels.api as sm
model = sm.OLS(y, X)    #OLS: Ordinary Least Square
result = model.fit()
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.995
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                          1.063e+04
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):                   6.70e-228
# Time:                        12:08:40   Log-Likelihood:                         -1424.3
# No. Observations:                 200   AIC:                                      2857.
# Df Residuals:                     196   BIC:                                      2870.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Por          139.9858      9.156     15.289      0.000     121.929     158.043
# Brittle       22.5223      1.249     18.035      0.000      20.059      24.985
# Perm         151.9626     18.123      8.385      0.000     116.221     187.704
# TOC          501.5845     61.704      8.129      0.000     379.895     623.273
# ==============================================================================
# Omnibus:                        0.770   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.680   Jarque-Bera (JB):                0.731
# Skew:                           0.147   Prob(JB):                        0.694
# Kurtosis:                       2.957   Cond. No.                         152.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#df에서 X변수들간의 correlation을 체크
#por 변수와 함께, corr이 낮은 X 변수들을 선택
df.corr()
X = df[["Por", "AI", "Brittle"]]
y = df.Prod
#X 변수를 scaling
scaled = StandardScaler().fit_transform( X)

#파티셔닝(7:3)
X_train, X_test, y_train, y_test = train_test_split( scaled, y, test_size=0.3)

#sm.OLS로 회귀모형을 model, 계수에 대한 p-value와 결정계수를 확인
import statsmodels.api as sm
X_train = sm.add_constant( X_train)
model = sm.OLS( y_train, X_train)
print( model.fit().summary() )
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Prod   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     763.7
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):           7.15e-85
# Time:                        12:08:40   Log-Likelihood:                -964.44
# No. Observations:                 140   AIC:                             1937.
# Df Residuals:                     136   BIC:                             1949.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4326.4651     20.548    210.551      0.000    4285.830    4367.101
# x1           968.0712     23.509     41.178      0.000     921.580    1014.562
# x2           -20.5331     24.034     -0.854      0.394     -68.062      26.995
# x3           395.5696     21.362     18.517      0.000     353.325     437.815
# ==============================================================================
# Omnibus:                        8.762   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.950
# Skew:                          -0.499   Prob(JB):                       0.0114
# Kurtosis:                       3.733   Cond. No.                         1.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_test.shape
# Out:
# (60, 3)

# %%
X = df[features]  #.values.reshape(-1, len(features))
y = df[target].values
X = sm.add_constant(X)
model = sm.OLS(y, X)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     960.6
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):          4.54e-127
# Time:                        12:08:40   Log-Likelihood:                -1360.2
# No. Observations:                 200   AIC:                             2730.
# Df Residuals:                     195   BIC:                             2747.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1575.2735    119.064    -13.231      0.000   -1810.091   -1340.456
# Por          244.6001     10.340     23.655      0.000     224.207     264.994
# Brittle       31.5880      1.138     27.752      0.000      29.343      33.833
# Perm          86.8737     14.077      6.171      0.000      59.110     114.637
# TOC          325.1935     46.844      6.942      0.000     232.807     417.580
# ==============================================================================
# Omnibus:                       31.387   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.877
# Skew:                          -0.869   Prob(JB):                     2.44e-11
# Kurtosis:                       4.686   Cond. No.                         404.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
reg = sm.OLS.from_formula("Prod ~ Por+Brittle+Perm+TOC", df).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Prod   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     960.6
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):          4.54e-127
# Time:                        12:08:40   Log-Likelihood:                -1360.2
# No. Observations:                 200   AIC:                             2730.
# Df Residuals:                     195   BIC:                             2747.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1575.2735    119.064    -13.231      0.000   -1810.091   -1340.456
# Por          244.6001     10.340     23.655      0.000     224.207     264.994
# Brittle       31.5880      1.138     27.752      0.000      29.343      33.833
# Perm          86.8737     14.077      6.171      0.000      59.110     114.637
# TOC          325.1935     46.844      6.942      0.000     232.807     417.580
# ==============================================================================
# Omnibus:                       31.387   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.877
# Skew:                          -0.869   Prob(JB):                     2.44e-11
# Kurtosis:                       4.686   Cond. No.                         404.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.formula.api import ols
model = ols(formula = "Prod ~ Por+Brittle+Perm+TOC",data = df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Prod   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     960.6
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):          4.54e-127
# Time:                        12:08:40   Log-Likelihood:                -1360.2
# No. Observations:                 200   AIC:                             2730.
# Df Residuals:                     195   BIC:                             2747.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1575.2735    119.064    -13.231      0.000   -1810.091   -1340.456
# Por          244.6001     10.340     23.655      0.000     224.207     264.994
# Brittle       31.5880      1.138     27.752      0.000      29.343      33.833
# Perm          86.8737     14.077      6.171      0.000      59.110     114.637
# TOC          325.1935     46.844      6.942      0.000     232.807     417.580
# ==============================================================================
# Omnibus:                       31.387   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.877
# Skew:                          -0.869   Prob(JB):                     2.44e-11
# Kurtosis:                       4.686   Cond. No.                         404.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = df.loc[0:10, features]
model.predict(X)
# Out:
# 0     4581.655627
# 1     3507.380732
# 2     4668.052396
# 3     4941.935607
# 4     3943.748339
# 5     4395.427883
# 6     4309.754307
# 7     3418.971205
# 8     4109.893694
# 9     4469.807278
# 10    4766.440056
# dtype: float64

# %% [markdown]
# #3. 머신러닝 회귀

# %%
# !pip install rfpimp
# Out:
# Requirement already satisfied: rfpimp in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (1.3.7)
# Requirement already satisfied: numpy in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from rfpimp) (2.4.2)
# Requirement already satisfied: pandas in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from rfpimp) (2.3.3)
# Requirement already satisfied: scikit-learn in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from rfpimp) (1.8.0)
# Requirement already satisfied: matplotlib in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from rfpimp) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from matplotlib->rfpimp) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from python-dateutil>=2.7->matplotlib->rfpimp) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from pandas->rfpimp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from pandas->rfpimp) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from scikit-learn->rfpimp) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from scikit-learn->rfpimp) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\user\miniconda3\envs\day3\Lib\site-packages (from scikit-learn->rfpimp) (3.6.0)

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

df = pd.read_csv('unconv_MV_v5.csv')
features = ['Por', 'Perm', 'AI', 'Brittle', 'TOC', 'VR', 'Prod']

#전처리
df_train, df_test = train_test_split(df, test_size=0.20)
df_train = df_train[features]
df_test = df_test[features]

X_train, y_train = df_train.drop('Prod',axis=1), df_train['Prod']
X_test, y_test = df_test.drop('Prod',axis=1), df_test['Prod']

#학습

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

np.mean( (y_test - dt.predict(X_test))**2)
# Out:
# np.float64(155928.952676159)

# %%
import rfpimp
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

df = pd.read_csv('unconv_MV_v5.csv')
features = ['Por', 'Perm', 'AI', 'Brittle', 'TOC', 'VR', 'Prod']

#전처리
df_train, df_test = train_test_split(df, test_size=0.20)
df_train = df_train[features]
df_test = df_test[features]

X_train, y_train = df_train.drop('Prod',axis=1), df_train['Prod']
X_test, y_test = df_test.drop('Prod',axis=1), df_test['Prod']

#학습

rf = RandomForestRegressor(n_estimators=100, n_jobs=-1)
rf.fit(X_train, y_train)

print( np.mean( (y_test - rf.predict(X_test))**2) )

#변수 중요도 및 시각화
imp = rfpimp.importances(rf, X_test, y_test)

fig, ax = plt.subplots(figsize=(6, 3))
ax.barh(imp.index, imp['Importance'], height=0.8, facecolor='grey', alpha=0.8, edgecolor='k')
ax.set_xlabel('Importance score')
plt.gca().invert_yaxis()
fig.tight_layout()
# Out:
# 57437.46301249964

# %% [markdown]
# #4. 실습2: CNC 데이터
# - Passorfail: 1 또는 0

# %%
df = pd.read_csv("정밀가공_품질보증_데이터셋.csv")

# %%
df.head()
# Out:
#            SerialNo         ReceivedDateTime  SpindleSpeed_max  \
# 0  20220823-0000185  2022-08-23 03:14:36.906           2227.05
# 1  20220823-0000186  2022-08-23 03:14:37.884           2227.05
# 2  20220823-0000187  2022-08-23 03:15:50.892           2227.05
# 3  20220823-0000188  2022-08-23 03:17:13.888           2224.02
# 4  20220823-0000189  2022-08-23 03:18:26.904           2225.03
#
#    ServoCurrent_X_max  ServoCurrent_Z1_max  ServoCurrent_Z2_max  \
# 0             1429.15              1364.51                 30.3
# 1             1510.96              3144.13                 30.3
# 2             1068.58              3144.13                 30.3
# 3              937.28              2377.54                 30.3
# 4              681.75              2377.54                 30.3
#
#    ServoCurrent_Z3_max  ServoLoad_X_max  ServoLoad_Z1_max  ServoLoad_Z2_max  \
# 0              4188.47           118.17             85.85              30.3
# 1              4188.47           154.53            173.72              30.3
# 2              4579.34           147.46             93.93              30.3
# 3              4183.42           184.83            220.18              30.3
# 4              4556.11           177.76            220.18              30.3
#
#    ...  ServoCurrent_Z3_std  ServoLoad_X_std  ServoLoad_Z1_std  \
# 0  ...           482.595381        19.046612         13.226897
# 1  ...           568.919411        21.173073         18.608439
# 2  ...           363.842687        18.603881         12.620133
# 3  ...           479.244638        22.790164         23.841988
# 4  ...           492.930251        21.737386         24.969696
#
#    ServoLoad_Z2_std  ServoLoad_Z3_std  SpindleLoad_max  SpindleLoad_mean  \
# 0               0.0        478.681055      31398.31238       4271.395985
# 1               0.0         59.504038      32008.19381       3241.446411
# 2               0.0         46.232507      31502.08988       3515.539294
# 3               0.0        479.783979      31207.89506       3391.720514
# 4               0.0        337.164170      32091.01381       3114.918299
#
#    SpindleLoad_min  SpindleLoad_std  passorfail
# 0              0.0      5320.503114           0
# 1              0.0      5001.031891           0
# 2              0.0      4963.334281           0
# 3              0.0      4736.149889           0
# 4              0.0      4825.433523           0
#
# [5 rows x 43 columns]

# %%
# 시간 컬럼을 datetime 형식으로 변환
df['ReceivedDateTime'] = pd.to_datetime(df['ReceivedDateTime'])
df.set_index('SerialNo', inplace=True)

# %%
# 1분 단위로 평균값 리샘플링
df_resampled = df.set_index('ReceivedDateTime').resample('10min')
df_resampled.mean().reset_index()
# Out:
#        ReceivedDateTime  SpindleSpeed_max  ServoCurrent_X_max  \
# 0   2022-08-23 03:10:00       2226.040000         1125.544000
# 1   2022-08-23 03:20:00       2226.418750         1209.601250
# 2   2022-08-23 03:30:00       2226.671250         1414.757500
# 3   2022-08-23 03:40:00       2224.881386          986.005286
# 4   2022-08-23 03:50:00       2226.934972         1032.999944
# ..                  ...               ...                 ...
# 326 2022-08-25 09:30:00       2224.741429         1065.117143
# 327 2022-08-25 09:40:00       2225.787500         1025.021225
# 328 2022-08-25 09:50:00       2224.424000          985.535780
# 329 2022-08-25 10:00:00       2226.376667         1245.835000
# 330 2022-08-25 10:10:00       2225.434000         1051.607960
#
#      ServoCurrent_Z1_max  ServoCurrent_Z2_max  ServoCurrent_Z3_max  \
# 0            2481.570000                 30.3          4339.162000
# 1            2258.991250                 30.3          4468.366250
# 2            2118.475000                 30.3          3771.718750
# 3            2162.410000                 30.3          4386.285714
# 4            1970.958889                 30.3          3919.136667
# ..                   ...                  ...                  ...
# 326          2674.480000                 30.3          4465.498571
# 327          2404.557500                 30.3          4352.468750
# 328          2430.969000                 30.3          3274.218000
# 329          2639.803333                 30.3          3854.833333
# 330          2381.984000                 30.3          3635.394000
#
#      ServoLoad_X_max  ServoLoad_Z1_max  ServoLoad_Z2_max  ServoLoad_Z3_max  \
# 0         156.550000        158.772000              30.3       2685.388000
# 1         158.948750        168.038750              30.3       2781.540000
# 2         146.576250        145.061250              30.3        928.063750
# 3         140.534286        168.525714              30.3       2053.762857
# 4         158.682222        158.008889              30.3       2479.662222
# ..               ...               ...               ...               ...
# 326       157.415714        160.590000              30.3       2039.045714
# 327       141.905000        157.055000              30.3       1843.628750
# 328       134.936000        132.815000              30.3       1933.241000
# 329       142.915000        134.666667              30.3       2929.673333
# 330       124.836000         93.930000              30.3       1098.476000
#
#      ...  ServoCurrent_Z3_std  ServoLoad_X_std  ServoLoad_Z1_std  \
# 0    ...           477.506474        20.670223         18.653431
# 1    ...           557.646706        20.928086         21.901756
# 2    ...           490.457734        19.592584         19.028410
# 3    ...           476.244044        18.507282         22.625356
# 4    ...           471.660944        19.155532         19.371680
# ..   ...                  ...              ...               ...
# 326  ...           549.960394        20.640053         20.279956
# 327  ...           472.786144        19.447256         18.650911
# 328  ...           440.573689        18.667285         16.562112
# 329  ...           454.297454        19.314570         16.380185
# 330  ...           412.915870        18.705286         14.569804
#
#      ServoLoad_Z2_std  ServoLoad_Z3_std  SpindleLoad_max  SpindleLoad_mean  \
# 0                 0.0        280.273150     31641.500988       3507.004100
# 1                 0.0        249.433842     31622.579219       3403.381734
# 2                 0.0        116.200458     31879.413255       3395.349338
# 3                 0.0        184.274116     31763.116389       3291.072711
# 4                 0.0        218.574741     31724.214817       3293.266851
# ..                ...               ...              ...               ...
# 326               0.0        178.004514     31691.849834       3203.360518
# 327               0.0        187.936787     31942.149519       3568.271541
# 328               0.0        204.208732     31802.397250       3584.552361
# 329               0.0        284.993146     31856.746835       3623.745595
# 330               0.0        126.345359     32127.888082       3573.477315
#
#      SpindleLoad_min  SpindleLoad_std  passorfail
# 0                0.0      4969.290539    0.000000
# 1                0.0      5009.177779    0.000000
# 2                0.0      5020.183103    0.000000
# 3                0.0      4972.512444    0.142857
# 4                0.0      4966.170943    0.111111
# ..               ...              ...         ...
# 326              0.0      4838.593939    0.000000
# 327              0.0      5058.795607    0.125000
# 328              0.0      5024.159057    0.100000
# 329              0.0      5034.237724    0.000000
# 330              0.0      5050.845662    0.200000
#
# [331 rows x 42 columns]

# %%
df2 = df_resampled.mean().reset_index()

# %%
# passorfail은 다수결 기준 (1분간 pass의 비율)
passfail = df.set_index('ReceivedDateTime').resample('10min')['passorfail']. mean().reset_index()
passfail['passorfail']
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.142857
# 4      0.111111
#          ...
# 326    0.000000
# 327    0.125000
# 328    0.100000
# 329    0.000000
# 330    0.200000
# Name: passorfail, Length: 331, dtype: float64

# %%
df2['passorfail'] = passfail['passorfail']

# %%
df2
# Out:
#        ReceivedDateTime  SpindleSpeed_max  ServoCurrent_X_max  \
# 0   2022-08-23 03:10:00       2226.040000         1125.544000
# 1   2022-08-23 03:20:00       2226.418750         1209.601250
# 2   2022-08-23 03:30:00       2226.671250         1414.757500
# 3   2022-08-23 03:40:00       2224.881386          986.005286
# 4   2022-08-23 03:50:00       2226.934972         1032.999944
# ..                  ...               ...                 ...
# 326 2022-08-25 09:30:00       2224.741429         1065.117143
# 327 2022-08-25 09:40:00       2225.787500         1025.021225
# 328 2022-08-25 09:50:00       2224.424000          985.535780
# 329 2022-08-25 10:00:00       2226.376667         1245.835000
# 330 2022-08-25 10:10:00       2225.434000         1051.607960
#
#      ServoCurrent_Z1_max  ServoCurrent_Z2_max  ServoCurrent_Z3_max  \
# 0            2481.570000                 30.3          4339.162000
# 1            2258.991250                 30.3          4468.366250
# 2            2118.475000                 30.3          3771.718750
# 3            2162.410000                 30.3          4386.285714
# 4            1970.958889                 30.3          3919.136667
# ..                   ...                  ...                  ...
# 326          2674.480000                 30.3          4465.498571
# 327          2404.557500                 30.3          4352.468750
# 328          2430.969000                 30.3          3274.218000
# 329          2639.803333                 30.3          3854.833333
# 330          2381.984000                 30.3          3635.394000
#
#      ServoLoad_X_max  ServoLoad_Z1_max  ServoLoad_Z2_max  ServoLoad_Z3_max  \
# 0         156.550000        158.772000              30.3       2685.388000
# 1         158.948750        168.038750              30.3       2781.540000
# 2         146.576250        145.061250              30.3        928.063750
# 3         140.534286        168.525714              30.3       2053.762857
# 4         158.682222        158.008889              30.3       2479.662222
# ..               ...               ...               ...               ...
# 326       157.415714        160.590000              30.3       2039.045714
# 327       141.905000        157.055000              30.3       1843.628750
# 328       134.936000        132.815000              30.3       1933.241000
# 329       142.915000        134.666667              30.3       2929.673333
# 330       124.836000         93.930000              30.3       1098.476000
#
#      ...  ServoCurrent_Z3_std  ServoLoad_X_std  ServoLoad_Z1_std  \
# 0    ...           477.506474        20.670223         18.653431
# 1    ...           557.646706        20.928086         21.901756
# 2    ...           490.457734        19.592584         19.028410
# 3    ...           476.244044        18.507282         22.625356
# 4    ...           471.660944        19.155532         19.371680
# ..   ...                  ...              ...               ...
# 326  ...           549.960394        20.640053         20.279956
# 327  ...           472.786144        19.447256         18.650911
# 328  ...           440.573689        18.667285         16.562112
# 329  ...           454.297454        19.314570         16.380185
# 330  ...           412.915870        18.705286         14.569804
#
#      ServoLoad_Z2_std  ServoLoad_Z3_std  SpindleLoad_max  SpindleLoad_mean  \
# 0                 0.0        280.273150     31641.500988       3507.004100
# 1                 0.0        249.433842     31622.579219       3403.381734
# 2                 0.0        116.200458     31879.413255       3395.349338
# 3                 0.0        184.274116     31763.116389       3291.072711
# 4                 0.0        218.574741     31724.214817       3293.266851
# ..                ...               ...              ...               ...
# 326               0.0        178.004514     31691.849834       3203.360518
# 327               0.0        187.936787     31942.149519       3568.271541
# 328               0.0        204.208732     31802.397250       3584.552361
# 329               0.0        284.993146     31856.746835       3623.745595
# 330               0.0        126.345359     32127.888082       3573.477315
#
#      SpindleLoad_min  SpindleLoad_std  passorfail
# 0                0.0      4969.290539    0.000000
# 1                0.0      5009.177779    0.000000
# 2                0.0      5020.183103    0.000000
# 3                0.0      4972.512444    0.142857
# 4                0.0      4966.170943    0.111111
# ..               ...              ...         ...
# 326              0.0      4838.593939    0.000000
# 327              0.0      5058.795607    0.125000
# 328              0.0      5024.159057    0.100000
# 329              0.0      5034.237724    0.000000
# 330              0.0      5050.845662    0.200000
#
# [331 rows x 42 columns]

# %%
corr = df2.corr(numeric_only=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True, sep=100)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0, linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# - Scaling, Partitioning, Regression

# %%
# 상관계수: 0.3 이상 또는 -0.3 이하
correlations = df.corr(numeric_only=True)['passorfail']

important_corr = correlations[(correlations >= 0.3) | (correlations <= -0.3)]

# 자기 자신 제거
important_corr = important_corr.drop('passorfail', errors='ignore')

important_corr
# Out:
# SpindleSpeed_max      -0.482542
# ServoCurrent_X_mean   -0.347268
# SpindleLoad_max        0.307452
# Name: passorfail, dtype: float64

# %% [markdown]
# # 거래량과 종가

# %%
# !pip install yfinance -q

# %%
import yfinance as yf

# 삼성전자 (예: 005930.KS), 기간: 최근 6개월
ticker = '005930.KS'  # '.KS'는 한국거래소(KRX) 종목
stock = yf.Ticker(ticker)

# 주가 데이터 다운로드 (시작일~종료일 지정)
df = stock.history(start="2024-01-01", end="2024-06-01")

# 결과 확인
print(df.head())
df = stock.history(period="1mo")
# Out:
#                                    Open          High           Low  \
# Date
# 2024-01-02 00:00:00+09:00  74930.033782  76463.129103  74930.033782
# 2024-01-03 00:00:00+09:00  75217.503703  75504.959131  73780.226562
# 2024-01-04 00:00:00+09:00  72917.860742  74067.682462  72917.860742
# 2024-01-05 00:00:00+09:00  73492.771602  73876.045508  73205.316172
# 2024-01-08 00:00:00+09:00  73780.225184  74259.317555  73205.314338
#
#                                   Close    Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00+09:00  76271.492188  17142847        0.0           0.0
# 2024-01-03 00:00:00+09:00  73780.226562  21753644        0.0           0.0
# 2024-01-04 00:00:00+09:00  73396.953125  15324439        0.0           0.0
# 2024-01-05 00:00:00+09:00  73396.953125  11304316        0.0           0.0
# 2024-01-08 00:00:00+09:00  73301.132812  11088724        0.0           0.0

# %%
# 어제 거래량 컬럼 생성 (lag)
df['Volume_lag1'] = df['Volume'].shift(1)

# NaN 제거 (첫 행은 어제 데이터 없음)
df = df.dropna()

# 결과 확인
print(df[['Close', 'Volume', 'Volume_lag1']].head())
# Out:
#                               Close    Volume  Volume_lag1
# Date
# 2026-03-17 00:00:00+09:00  193900.0  20300082   19747901.0
# 2026-03-18 00:00:00+09:00  208500.0  25148481   20300082.0
# 2026-03-19 00:00:00+09:00  200500.0  19884483   25148481.0
# 2026-03-20 00:00:00+09:00  199400.0  35279762   19884483.0
# 2026-03-23 00:00:00+09:00  186300.0  30268173   35279762.0

# %% [markdown]
# # 범주형 변수와 교호작용

# %%
import pandas as pd

# 데이터 생성
data = pd.DataFrame({
    'EngineSize': [1.6, 2.0, 3.0, 1.4, 2.2, 2.5, 3.5, 1.2],
    'FuelType': ['Gasoline', 'Diesel', 'Gasoline', 'Diesel', 'Gasoline', 'Diesel', 'Gasoline', 'Diesel'],
    'Price': [18000, 22000, 27000, 16000, 24000, 25000, 32000, 15000]
})

# %%
# 범주형 변수 'FuelType'을 더미변수로 변환
data_encoded = pd.get_dummies(data, columns=['FuelType'], drop_first=True)
data_encoded['Interaction'] = data_encoded['EngineSize'] * data_encoded['FuelType_Gasoline']
print(data_encoded)
# Out:
#    EngineSize  Price  FuelType_Gasoline  Interaction
# 0         1.6  18000               True          1.6
# 1         2.0  22000              False          0.0
# 2         3.0  27000               True          3.0
# 3         1.4  16000              False          0.0
# 4         2.2  24000               True          2.2
# 5         2.5  25000              False          0.0
# 6         3.5  32000               True          3.5
# 7         1.2  15000              False          0.0

# %%
# 회귀 모델 적합
from statsmodels.formula.api import ols
model = ols(formula='Price~EngineSize+FuelType_Gasoline+Interaction', data=data_encoded).fit()

# 결과 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     70.43
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):           0.000643
# Time:                        12:18:55   Log-Likelihood:                -64.240
# No. Observations:                   8   AIC:                             136.5
# Df Residuals:                       4   BIC:                             136.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  5181.3842   1897.178      2.731      0.052     -86.026    1.04e+04
# FuelType_Gasoline[T.True]  2488.4160   2705.338      0.920      0.410   -5022.806    9999.638
# EngineSize                 8066.8258   1027.003      7.855      0.001    5215.408    1.09e+04
# Interaction               -1239.5637   1254.610     -0.988      0.379   -4722.920    2243.793
# ==============================================================================
# Omnibus:                        0.188   Durbin-Watson:                   2.739
# Prob(Omnibus):                  0.910   Jarque-Bera (JB):                0.337
# Skew:                           0.234   Prob(JB):                        0.845
# Kurtosis:                       2.110   Cond. No.                         28.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.linear_model import LinearRegression
# 독립변수(X)와 종속변수(y) 설정
X = data_encoded[['EngineSize', 'FuelType_Gasoline', 'Interaction']]
y = data_encoded['Price']

# 모델 학습
reg = LinearRegression()
reg.fit(X, y)

# 계수 출력
print("절편:", reg.intercept_)
print("회귀계수:", reg.coef_)
# Out:
# 절편: 5181.384248210026
# 회귀계수: [ 8066.82577566  2488.41598681 -1239.563731  ]
